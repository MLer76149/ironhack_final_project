# %%
import numpy as np
import pandas as pd
import re
from sklearn.model_selection import train_test_split
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('tagsets')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import seaborn as sns
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/ironhack-final-project')

# %%
import you_nlp

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ironhack-final-project/raw_data/CAvideos_final_cleaned.csv")

# %%
data_nlp, frq = you_nlp.get_key_words(data, "en")

# %%
stop_words = list(stopwords.words('english'))

# %%
key_word_df, final_freq = you_nlp.create_keywords_df(data_nlp, frq, stop_words, "CA_EN")

# %%
sns.displot(key_word_df["views"])

# %%
key_word_df_outl = you_nlp.remove_outliers(key_word_df)
# Out:
# category_id
# 5.0
# 31.5
# 11.5
# views
# 864872.25
# 2321685.375
# -1137803.625
# likes
# 27966.25
# 72754.625
# -39110.375
# dislikes
# 893.0
# 2344.5
# -1227.5
# comment_count
# 3569.25
# 9427.875
# -4849.125
# likes_rate
# 0.03712489255118617
# 0.10436200172927308
# -0.04413756847547161
# dislikes_rate
# 0.0008540533349926251
# 0.0026364639369786625
# -0.0007797494029918376
# new
# 1.0
# 2.5
# -1.5
# news
# video
# 2.0
# 5.0
# -3.0
# nfollow
# youtube
# facebook
# 1.0
# 2.5
# -1.5
# subscribe
# 1.0
# 2.5
# -1.5
# best
# get
# instagram
# live
# nsubscribe
# latest
# nfacebook
# song
# ntwitter
# ninstagram
# nthe
# movie
# use
# late
# punjabi
# com
# nwatch
# follow
# every
# nba
# react
# makeup
# nlike
# getty
# free
# nmusic
# film
# jimmy
# game
# james
# episode
# online
# kid
# series
# iphone
# got
# please
# christmas
# nget
# review
# donald
# ever
# made
# also
# 0 rows have been removed, 0.0% in total

# %%
sns.displot(key_word_df_outl["views"])

# %%
key_word_df_outl["views"].describe()
# Out:
# count    2.073000e+04
# mean     4.183631e+05
# std      4.194483e+05
# min      1.369000e+03
# 25%      1.250792e+05
# 50%      2.770420e+05
# 75%      5.653810e+05
# max      2.320810e+06
# Name: views, dtype: float64

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df, "likes", "CA_EN_Likes")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Please enter k:3
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:165: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.7794266148443767
# MSE: 4296540038.585023
# RMSE: 65547.99797541511
# MAE: 15381.322912636713
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.7041966695219928
# MSE: 5916233758.800265
# RMSE: 76917.05765823512
# MAE: 22815.92673760508
# -----------------------------
# Filename Linear: CA_EN_Likes_random_forest.sav
# -----------------------------
# ...

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df_outl, "likes", "CA_EN_Likes_Out")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Please enter k:3
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:166: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.8471932058378657
# MSE: 24873486.61365412
# RMSE: 4987.332615101395
# MAE: 2885.0861124600715
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.5787244810216995
# MSE: 71830649.76969783
# RMSE: 8475.29644140533
# MAE: 5012.791496511727
# -----------------------------
# Filename Linear: CA_EN_Likes_Out_random_forest.sav
# -----------------------------
# ...

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df, "likes_rate", "CA_EN_Likes_Rate")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Please enter k:3
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:165: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.81040108409636
# MSE: 0.00016575783335451413
# RMSE: 0.012874697408269995
# MAE: 0.006809535877278753
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.5646463606150092
# MSE: 0.0003678874971389919
# RMSE: 0.0191803935605866
# MAE: 0.01120182028334657
# -----------------------------
# Filename Linear: CA_EN_Likes_Rate_random_forest.sav
# ...

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df_outl, "likes_rate", "CA_EN_Likes_Rate_Out")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Please enter k:3
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:166: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.8626430166755654
# MSE: 7.221302033844325e-05
# RMSE: 0.008497824447377296
# MAE: 0.005022286422211845
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.6530704096135702
# MSE: 0.0001804758723842062
# RMSE: 0.013434130875654227
# MAE: 0.008469647846875606
# -----------------------------
# Filename Linear: CA_EN_Likes_Rate_Out_random_forest.sav
# ...

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df, "views", "CA_EN_Views")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Please enter k:3
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:165: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.7347678443442882
# MSE: 3153215059903.3022
# RMSE: 1775729.4444546732
# MAE: 511248.4896381713
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.6621309991278782
# MSE: 4786901020486.904
# RMSE: 2187898.7683361643
# MAE: 758065.7083986407
# -----------------------------
# Filename Linear: CA_EN_Views_random_forest.sav
# -----------------------------
# ...

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df_outl, "views", "CA_EN_Views_Out")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Please enter k:7
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:166: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.7313195746093825
# MSE: 48013676789.83502
# RMSE: 219120.23363860085
# MAE: 137897.90418425138
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.3941553240440647
# MSE: 102648475104.38287
# RMSE: 320388.00711696886
# MAE: 215512.72887781722
# -----------------------------
# Filename Linear: CA_EN_Views_Out_random_forest.sav
# -----------------------------
# ...

# %%
max_depth_choices=[3,4,5,6,7,8,9,10,None]
min_sample_split=[5 , 10, 15]
min_sample_leaf=[5, 10, 15]
max_samples=[0.2, 0.6, 0.8, 0.9]
random_state=[5, 10, 13]

# %%
random_forest = {'max_depth': max_depth_choices,    
                'min_samples_split': min_sample_split,
                'min_samples_leaf': min_sample_leaf,
                'max_samples': max_samples,
                'random_state': random_state
               }
