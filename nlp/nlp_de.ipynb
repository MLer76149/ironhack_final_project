# %%
import numpy as np
import pandas as pd
import re
from sklearn.model_selection import train_test_split
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('tagsets')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import seaborn as sns
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets.zip.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/ironhack-final-project')

# %%
import you_nlp

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ironhack-final-project/raw_data/DEvideos_final_cleaned.csv")

# %%
data_nlp, frq = you_nlp.get_key_words(data, "de")

# %%
stop_words = list(stopwords.words('german'))

# %%
stop_words
# Out:
# ['aber',
#  'alle',
#  'allem',
#  'allen',
#  'aller',
#  'alles',
#  'als',
#  'also',
#  'am',
#  'an',
#  'ander',
#  'andere',
#  'anderem',
#  'anderen',
#  'anderer',
#  'anderes',
#  'anderm',
#  'andern',
#  'anderr',
#  'anders',
#  'auch',
#  'auf',
#  'aus',
#  'bei',
#  'bin',
#  'bis',
#  'bist',
#  'da',
#  'damit',
#  'dann',
#  'der',
#  'den',
#  'des',
#  'dem',
#  'die',
#  'das',
#  'dass',
#  'daß',
#  'derselbe',
#  'derselben',
#  'denselben',
#  'desselben',
#  'demselben',
#  'dieselbe',
#  'dieselben',
#  'dasselbe',
#  'dazu',
#  'dein',
#  'deine',
#  'deinem',
#  'deinen',
#  'deiner',
#  'deines',
#  'denn',
#  'derer',
#  'dessen',
#  'dich',
#  'dir',
#  'du',
#  'dies',
#  'diese',
#  'diesem',
#  'diesen',
#  'dieser',
#  'dieses',
#  'doch',
#  'dort',
#  'durch',
#  'ein',
#  'eine',
#  'einem',
#  'einen',
#  'einer',
#  'eines',
#  'einig',
#  'einige',
#  'einigem',
#  'einigen',
#  'einiger',
#  'einiges',
#  'einmal',
#  'er',
#  'ihn',
# ...

# %%
key_word_df, final_freq = you_nlp.create_keywords_df(data_nlp, frq, stop_words, "DE_DE")

# %%
key_word_df_outl = you_nlp.remove_outliers(key_word_df)
# Out:
# category_id
# 2.0
# 27.0
# 19.0
# views
# 120850.75
# 312507.875
# -170895.125
# likes
# 5650.5
# 14473.0
# -8129.0
# dislikes
# 213.0
# 546.5
# -305.5
# comment_count
# 630.0
# 1624.0
# -896.0
# likes_rate
# 0.0494922164881169
# 0.1442296922147645
# -0.053739173737703066
# dislikes_rate
# 0.0019477226682991248
# 0.005622918937711462
# -0.002167971735485037
# facebook
# 1.0
# 2.5
# -1.5
# youtube
# instagram
# 1.0
# 2.5
# -1.5
# mehr
# 1.0
# 2.5
# -1.5
# kanal
# video
# 1.0
# 2.5
# -1.5
# abonnieren
# de
# 1.0
# 2.5
# -1.5
# deutsch
# twitter
# ndie
# gibt
# dazn
# mal
# folgen
# streife
# folge
# kamera
# geht
# ganze
# link
# 1.0
# 2.5
# -1.5
# neue
# ninstagram
# köln
# welt
# nfacebook
# immer
# musik
# dabei
# fifa
# provision
# news
# fußball
# by
# spaß
# live
# nmein
# produkte
# diy
# einfach
# leben
# of
# teil
# galileo
# the
# liebe
# natürlich
# nhier
# selber
# ntwitter
# heute
# 0 rows have been removed, 0.0% in total

# %%
key_word_df_outl.shape
# Out:
# (8806, 64)

# %%
final_freq
# Out:
# [('facebook', 8538),
#  ('youtube', 7844),
#  ('instagram', 7776),
#  ('mehr', 7118),
#  ('kanal', 6606),
#  ('video', 6591),
#  ('abonnieren', 5938),
#  ('de', 5332),
#  ('deutsch', 4644),
#  ('twitter', 4516),
#  ('ndie', 4041),
#  ('gibt', 3976),
#  ('dazn', 3748),
#  ('mal', 3530),
#  ('folgen', 3464),
#  ('streife', 3402),
#  ('folge', 3288),
#  ('kamera', 3279),
#  ('geht', 3192),
#  ('ganze', 3154),
#  ('link', 3148),
#  ('neue', 3116),
#  ('ninstagram', 3060),
#  ('köln', 3041),
#  ('welt', 3020),
#  ('nfacebook', 3007),
#  ('immer', 2980),
#  ('musik', 2855),
#  ('dabei', 2847),
#  ('fifa', 2845),
#  ('provision', 2813),
#  ('news', 2708),
#  ('fußball', 2611),
#  ('by', 2572),
#  ('spaß', 2545),
#  ('live', 2499),
#  ('nmein', 2445),
#  ('produkte', 2432),
#  ('diy', 2418),
#  ('einfach', 2374),
#  ('leben', 2344),
#  ('of', 2286),
#  ('teil', 2255),
#  ('galileo', 2232),
#  ('the', 2225),
#  ('liebe', 2161),
#  ('natürlich', 2134),
#  ('nhier', 2133),
#  ('selber', 2088),
# ...

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df, "likes", "DE_DE_Likes")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Please enter k:4
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:165: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.9157403885788984
# MSE: 21728534.135188945
# RMSE: 4661.387576161088
# MAE: 1826.778606590763
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.7929100529544704
# MSE: 69760172.61051592
# RMSE: 8352.255540302627
# MAE: 3288.0280818136107
# -----------------------------
# Filename Linear: DE_DE_Likes_random_forest.sav
# -----------------------------
# ...

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df_outl, "likes", "DE_DE_Likes_Out")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:3253: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# Please enter k:3
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:166: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.8734262513822162
# MSE: 853519.4232304594
# RMSE: 923.8611493241067
# MAE: 504.40608958484216
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.6259422958963965
# ...

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df, "likes_rate", "DE_DE_Likes_Rate")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Please enter k:3
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:165: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.8474585990141918
# MSE: 0.0002214085613620693
# RMSE: 0.014879803807915926
# MAE: 0.009150739828329452
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.5264100431040792
# MSE: 0.000728038707178569
# RMSE: 0.026982192408671484
# MAE: 0.01719656765448726
# -----------------------------
# Filename Linear: DE_DE_Likes_Rate_random_forest.sav
# ...

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df_outl, "likes_rate", "DE_DE_Likes_Rate_Out")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:3253: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# Please enter k:5
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:166: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.8293113402608134
# MSE: 0.00017909164016432092
# RMSE: 0.013382512475776771
# MAE: 0.008307209723655076
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.5358102250083018
# ...

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df, "views", "DE_DE_Views")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Please enter k:3
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:165: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.815476539769747
# MSE: 12156104191.425684
# RMSE: 110254.72412294034
# MAE: 47038.61014525357
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.6158059977363668
# MSE: 25968932957.240395
# RMSE: 161148.79136140115
# MAE: 77164.44844391555
# -----------------------------
# Filename Linear: DE_DE_Views_random_forest.sav
# -----------------------------
# ...

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df_outl, "views", "DE_DE_Views_Out")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:3253: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# Please enter k:5
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:166: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.7614222954535055
# MSE: 786400055.5750427
# RMSE: 28042.825385025717
# MAE: 16622.218691089736
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.37623181223488
# ...

# %%
max_depth_choices=[3,4,5,6,7,8,9,10,None]
min_sample_split=[5 , 10, 15]
min_sample_leaf=[5, 10, 15]
max_samples=[0.2, 0.6, 0.8, 0.9]
random_state=[5, 10, 13]

# %%
random_forest = {'max_depth': max_depth_choices,    
                'min_samples_split': min_sample_split,
                'min_samples_leaf': min_sample_leaf,
                'max_samples': max_samples,
                'random_state': random_state
               }
