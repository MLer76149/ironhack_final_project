# %%
import numpy as np
import pandas as pd
import re
from sklearn.model_selection import train_test_split
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('tagsets')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import seaborn as sns
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets.zip.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/ironhack-final-project')

# %%
import you_nlp

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ironhack-final-project/raw_data/MXvideos_final_cleaned.csv")

# %%
data_nlp, frq = you_nlp.get_key_words(data, "es")

# %%
stop_words = list(stopwords.words('spanish'))

# %%
key_word_df, final_freq = you_nlp.create_keywords_df(data_nlp, frq, stop_words, "MX_ES")

# %%
final_freq
# Out:
# [('ةs', 15415),
#  ('صa', 13198),
#  ('nظ', 8245),
#  ('noticias', 7891),
#  ('nظû', 7537),
#  ('facebook', 7328),
#  ('espa', 6713),
#  ('mexico', 6600),
#  ('ةn', 6314),
#  ('hoy', 6089),
#  ('nfacebook', 6011),
#  ('redes', 5714),
#  ('ظû', 5677),
#  ('nuevo', 5485),
#  ('ol', 5348),
#  ('vida', 5336),
#  ('hacer', 5329),
#  ('رxico', 5277),
#  ('ntwitter', 5267),
#  ('instagram', 5256),
#  ('sociales', 5091),
#  ('vivo', 5037),
#  ('programa', 5006),
#  ('exatlon', 4532),
#  ('mx', 4529),
#  ('ninstagram', 4512),
#  ('صbete', 4501),
#  ('aqu', 4448),
#  ('mundo', 4342),
#  ('ser', 4254),
#  ('mejores', 4205),
#  ('oficial', 4165),
#  ('dios', 4163),
#  ('رs', 4103),
#  ('azteca', 4092),
#  ('amor', 3912),
#  ('completo', 3894),
#  ('liga', 3828),
#  ('mejor', 3755),
#  ('رn', 3718),
#  ('capitulo', 3700),
#  ('parte', 3687),
#  ('ver', 3535),
#  ('صdeo', 3454),
#  ('america', 3454),
#  ('youtube', 3452),
#  ('fichajes', 3433),
#  ('none', 3396),
#  ('futbol', 3388),
# ...

# %%
sns.displot(key_word_df["views"])

# %%
key_word_df_outl = you_nlp.remove_outliers(key_word_df)
# Out:
# category_id
# 2.0
# 27.0
# 19.0
# views
# 144301.75
# 376534.125
# -200672.875
# likes
# 5233.5
# 13389.75
# -7544.25
# dislikes
# 208.0
# 537.0
# -295.0
# comment_count
# 684.0
# 1755.0
# -981.0
# likes_rate
# 0.06964899850352102
# 0.18220336917460722
# -0.09639262483947686
# dislikes_rate
# 0.001257622096146075
# 0.003881586670687837
# -0.0011489017138964625
# ةs
# 1.0
# 2.5
# -1.5
# صa
# nظ
# noticias
# nظû
# facebook
# espa
# mexico
# ةn
# hoy
# nfacebook
# redes
# ظû
# nuevo
# ol
# vida
# hacer
# رxico
# ntwitter
# instagram
# sociales
# vivo
# programa
# exatlon
# mx
# ninstagram
# صbete
# aqu
# mundo
# ser
# mejores
# oficial
# dios
# رs
# azteca
# amor
# completo
# liga
# mejor
# رn
# capitulo
# parte
# ver
# صdeo
# america
# youtube
# fichajes
# none
# futbol
# com
# qu
# 0 rows have been removed, 0.0% in total

# %%
sns.displot(key_word_df_outl["views"])

# %%
key_word_df_outl["views"].describe()
# Out:
# count     14544.000000
# mean      54309.815044
# std       64669.175879
# min         559.000000
# 25%       11778.750000
# 50%       28596.500000
# 75%       70322.000000
# max      375622.000000
# Name: views, dtype: float64

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df, "likes", "MX_ES_Likes")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Please enter k:2
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:166: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.8542120829433058
# MSE: 177185768.48604065
# RMSE: 13311.11447197569
# MAE: 3619.626416325155
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.5907023465381169
# MSE: 449304120.7871121
# RMSE: 21196.79505932706
# MAE: 6627.939215971447
# -----------------------------
# Filename Linear: MX_ES_Likes_random_forest.sav
# -----------------------------
# ...

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df_outl, "likes", "MX_ES_Likes_Out")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Please enter k:8
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:166: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.8387695790820866
# MSE: 974110.8695193457
# RMSE: 986.9705514955073
# MAE: 529.5290203359895
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.47019111406170566
# MSE: 3263708.314284219
# RMSE: 1806.573639319532
# MAE: 1032.4297659232186
# -----------------------------
# Filename Linear: MX_ES_Likes_Out_random_forest.sav
# -----------------------------
# ...

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df, "likes_rate", "MX_ES_Likes_Rate")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Please enter k:8
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:166: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.8654198807771423
# MSE: 0.0003252050304815998
# RMSE: 0.01803344200316733
# MAE: 0.010567187876561001
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.5634040151825548
# MSE: 0.0010459112264233565
# RMSE: 0.03234055080581276
# MAE: 0.02010676596483728
# -----------------------------
# Filename Linear: MX_ES_Likes_Rate_random_forest.sav
# ...

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df_outl, "likes_rate", "MX_ES_Likes_Rate_Out")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Please enter k:7
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:166: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.8545462636550406
# MSE: 0.0002654091331806404
# RMSE: 0.016291382175268015
# MAE: 0.009718168215542663
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.5633031806771354
# MSE: 0.0007760462527618276
# RMSE: 0.02785760673069077
# MAE: 0.017981114528333578
# -----------------------------
# Filename Linear: MX_ES_Likes_Rate_Out_random_forest.sav
# ...

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df, "views", "MX_ES_Views")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Please enter k:2
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:166: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.7794459066529392
# MSE: 127863557478.94931
# RMSE: 357580.14133750397
# MAE: 93344.15725538235
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.34661377065794163
# MSE: 353648374651.515
# RMSE: 594683.4238916661
# MAE: 165958.09864212194
# -----------------------------
# Filename Linear: MX_ES_Views_random_forest.sav
# -----------------------------
# ...

# %%
X_train, y_train, X_test, y_test, file_names = you_nlp.train_model(key_word_df_outl, "views", "MX_ES_Views_Out")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Please enter k:11
# /content/drive/MyDrive/Colab Notebooks/ironhack-final-project/you_nlp.py:166: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# -----------------------------
# --------Random Forest--------
# ----------Train Set----------
# -----------------------------
# R2: 0.6692275351320368
# MSE: 1390814954.5422049
# RMSE: 37293.63155476019
# MAE: 22561.553020602994
# -----------------------------
# --------Random Forest--------
# -----------Test Set----------
# -----------------------------
# R2: 0.14484942465130235
# MSE: 3530123521.5299134
# RMSE: 59414.842602921315
# MAE: 39349.48912014641
# -----------------------------
# Filename Linear: MX_ES_Views_Out_random_forest.sav
# -----------------------------
# ...

# %%
max_depth_choices=[3,4,5,6,7,8,9,10,None]
min_sample_split=[5 , 10, 15]
min_sample_leaf=[5, 10, 15]
max_samples=[0.2, 0.6, 0.8, 0.9]
random_state=[5, 10, 13]

# %%
random_forest = {'max_depth': max_depth_choices,    
                'min_samples_split': min_sample_split,
                'min_samples_leaf': min_sample_leaf,
                'max_samples': max_samples,
                'random_state': random_state
               }
